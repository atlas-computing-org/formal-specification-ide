// %% [markdown]
// # Semantic Categories

// %% [markdown]
// Pass a list of segments to the LLM and ask for labels and descriptions.

// %%
import { SystemMessage, HumanMessage } from "@langchain/core/messages";
import { ChatPromptTemplate, MessagesPlaceholder } from "@langchain/core/prompts";
import { JsonOutputParser } from "@langchain/core/output_parsers";
import { readFileSync } from 'node:fs';

import { EXPERIMENTS_DIR, SERVER_DATA_DIR } from '../server/src/util/fileUtils.ts';
import { getNotebookLogger } from '../server/src/Logger.ts';
import { newModel } from '../server/src/agents/agent.ts';

function splitText(text: string) {
  const segments = text.split('\n\n');
  const segind = [];
  let lastIndex = 0;
  for (const segment of segments) {
    segind.push({segment: segment, start: lastIndex, stop: lastIndex + segment.length});
    lastIndex += segment.length + 2; // +2 for the two newlines
  }
  const segindices = [];
  for (const {segment, start, stop} of segind) {
    if (segment !== '') {
      if (segment[0] === '\n') {
        segindices.push({segment: segment.slice(1), start: start+1, stop: stop});
      } else {
        segindices.push({segment, start, stop});
      }
    }
  }
  return segindices;
}

const prompt = ChatPromptTemplate.fromMessages([ new MessagesPlaceholder("messages") ]);
const llm = newModel("Anthropic");
const parser = new JsonOutputParser();
const chain = prompt.pipe(llm).pipe(parser);

const logger = getNotebookLogger();
const lhsText = readFileSync(`${SERVER_DATA_DIR}/AES-md/selected-text.txt`, 'utf-8');
const PROMPT = readFileSync(`${EXPERIMENTS_DIR}/annotateNodePromptCategories7.txt`, 'utf-8');

const lhsSegIndices = splitText(lhsText);
const lhsSegments = [];
for (let i = 0; i < lhsSegIndices.length; i++) {
  const {segment, start, stop} = lhsSegIndices[i];
  lhsSegments.push({text: segment, label: `${i}:${start}-${stop}`}); 
}

const userInput = JSON.stringify(lhsSegments, null, 2);
const output = await chain.invoke({ messages: [
  new SystemMessage(PROMPT),
  new HumanMessage(userInput)
]});
logger.info(output);
// Out:
// ```json
// [
//   {
//     "label": "0:0-29",
//     "description": "Section header introducing the algorithm specifications",
//     "category": "Navigation"
//   },
//   {
//     "label": "1:31-161",
//     "description": "Introduction of the general functions CIPHER() and INVCIPHER() for AES algorithms",
//     "category": "Definition"
//   },
//   {
//     "label": "2:163-361",
//     "description": "Footnote explaining why neutral terminology (CIPHER/INVCIPHER) is used instead of encryption/decryption",
//     "category": "Elaboration"
//   },
//   {
//     "label": "3:363-651",
//     "description": "Explanation of rounds and round keys as core components of the CIPHER and INVCIPHER algorithms",
//     "category": "Definition"
//   },
//   {
//     "label": "4:653-964",
//     "description": "Definition of the KEYEXPANSION routine that generates round keys from the cipher key",
//     "category": "Definition"
//   },
//   {
//     "label": "5:966-1560",
//     "description": "Explanation of the differences between AES-128, AES-192, and AES-256 in terms of key length, number of rounds, and key expansion",
//     "category": "Definition"
//   },
//   {
//     "label": "6:1562-1666",
//     "description": "Reference to another section for implementation issues related to key length, block size, and rounds",
//     "category": "Navigation"
//   },
//   {
//     "label": "7:1668-1935",
//     "description": "Table showing the key-block-round combinations for the three AES variants",
//     "category": "Parameter"
//   },
//   {
//     "label": "8:1937-2525",
//     "description": "Mathematical definition of the three AES variants in terms of the CIPHER function and its inputs",
//     "category": "Definition"
//   },
//   {
//     "label": "9:2527-2614",
//     "description": "Definition of inverse permutations by replacing CIPHER with INVCIPHER",
//     "category": "Definition"
//   },
//   {
//     "label": "10:2616-2734",
//     "description": "Navigation reference to sections containing specifications of CIPHER, KEYEXPANSION, and INVCIPHER",
//     "category": "Navigation"
//   },
//   {
//     "label": "11:2736-2751",
//     "description": "Section header for CIPHER() function",
//     "category": "Navigation"
//   },
//   {
//     "label": "12:2753-3128",
//     "description": "Overview of the four transformations that compose the rounds in CIPHER(): SubBytes, ShiftRows, MixColumns, and AddRoundKey",
//     "category": "Definition"
//   },
//   {
//     "label": "13:3130-3414",
//     "description": "Explanation of notation used in transformation specifications and reference to sections containing detailed specifications",
//     "category": "Elaboration"
//   },
//   {
//     "label": "14:3416-3600",
//     "description": "Explanation of how round keys for ADDROUNDKEY are generated by KEYEXPANSION",
//     "category": "Elaboration"
//   },
//   {
//     "label": "15:3602-3652",
//     "description": "Reference to the pseudocode for CIPHER() in Algorithm 1",
//     "category": "Navigation"
//   },
//   {
//     "label": "16:3654-4267",
//     "description": "Pseudocode implementation of the CIPHER() function showing the sequence of transformations",
//     "category": "Algorithm"
//   },
//   {
//     "label": "17:4269-4680",
//     "description": "Explanation of the steps in the CIPHER() algorithm, highlighting the difference in the final round",
//     "category": "Elaboration"
//   },
//   {
//     "label": "18:4682-4702",
//     "description": "Section header for SubBytes() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "19:4704-4907",
//     "description": "Definition of SUBBYTES() as an invertible, non-linear transformation using an S-box",
//     "category": "Definition"
//   },
//   {
//     "label": "20:4909-5116",
//     "description": "Introduction to the two-step construction of the S-box output byte",
//     "category": "Definition"
//   },
//   {
//     "label": "21:5118-5362",
//     "description": "First step of S-box transformation: computing the multiplicative inverse in the finite field",
//     "category": "Algorithm"
//   },
//   {
//     "label": "22:5364-5652",
//     "description": "Second step of S-box transformation: applying an affine transformation to the bits",
//     "category": "Algorithm"
//   },
//   {
//     "label": "23:5654-6464",
//     "description": "Matrix form representation of the affine transformation in the S-box",
//     "category": "Elaboration"
//   },
//   {
//     "label": "24:6466-6523",
//     "description": "Reference to Figure 2 illustrating the SUBBYTES transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "25:6525-6563",
//     "description": "Figure caption for illustration of SUBBYTES",
//     "category": "Diagram"
//   },
//   {
//     "label": "26:6565-6839",
//     "description": "Explanation of how to use the S-box table with an example",
//     "category": "Example"
//   },
//   {
//     "label": "27:6841-8575",
//     "description": "Table 4 showing the S-box substitution values in hexadecimal format",
//     "category": "Parameter"
//   },
//   {
//     "label": "28:8577-8598",
//     "description": "Section header for ShiftRows() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "29:8600-8917",
//     "description": "Mathematical definition of SHIFTROWS() as a cyclic shift of bytes in the last three rows of the state",
//     "category": "Algorithm"
//   },
//   {
//     "label": "30:8919-9178",
//     "description": "Elaboration on how SHIFTROWS() transforms the state by shifting bytes to the left",
//     "category": "Elaboration"
//   },
//   {
//     "label": "31:9180-9219",
//     "description": "Figure caption for illustration of SHIFTROWS",
//     "category": "Diagram"
//   },
//   {
//     "label": "32:9221-9243",
//     "description": "Section header for MixColumns() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "33:9245-9513",
//     "description": "Definition of MIXCOLUMNS() as a transformation that multiplies each column by a fixed matrix",
//     "category": "Definition"
//   },
//   {
//     "label": "34:9515-9890",
//     "description": "Matrix representation of the MIXCOLUMNS() transformation",
//     "category": "Algorithm"
//   },
//   {
//     "label": "35:9892-10445",
//     "description": "Expanded definition of individual output bytes in the MIXCOLUMNS() transformation",
//     "category": "Algorithm"
//   },
//   {
//     "label": "36:10447-10481",
//     "description": "Reference to Figure 4 illustrating MIXCOLUMNS",
//     "category": "Navigation"
//   },
//   {
//     "label": "37:10483-10523",
//     "description": "Figure caption for illustration of MIXCOLUMNS",
//     "category": "Diagram"
//   },
//   {
//     "label": "38:10525-10548",
//     "description": "Section header for AddRoundKey() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "39:10550-11389",
//     "description": "Definition of ADDROUNDKEY() as a transformation that combines the state with a round key using XOR",
//     "category": "Algorithm"
//   },
//   {
//     "label": "40:11391-11547",
//     "description": "Reference to Figure 5 illustrating ADDROUNDKEY with additional context about byte addressing",
//     "category": "Elaboration"
//   },
//   {
//     "label": "41:11549-11590",
//     "description": "Figure caption for illustration of ADDROUNDKEY",
//     "category": "Diagram"
//   },
//   {
//     "label": "42:11592-12171",
//     "description": "Pseudocode implementation of the KEYEXPANSION() function",
//     "category": "Algorithm"
//   },
//   {
//     "label": "43:12173-12253",
//     "description": "Reference to figures illustrating KEYEXPANSION for the three AES variants",
//     "category": "Navigation"
//   },
//   {
//     "label": "44:12255-12273",
//     "description": "Section header for INVCIPHER() function",
//     "category": "Navigation"
//   },
//   {
//     "label": "45:12275-12573",
//     "description": "Overview of INVCIPHER() as the inverse of CIPHER() with transformations executed in reverse order",
//     "category": "Definition"
//   },
//   {
//     "label": "46:12575-12703",
//     "description": "Reference to the pseudocode for INVCIPHER() in Algorithm 3",
//     "category": "Navigation"
//   },
//   {
//     "label": "47:12705-12848",
//     "description": "Figure caption for KEYEXPANSION of AES-128",
//     "category": "Diagram"
//   },
//   {
//     "label": "48:12850-12993",
//     "description": "Figure caption for KEYEXPANSION of AES-192",
//     "category": "Diagram"
//   },
//   {
//     "label": "49:12995-13138",
//     "description": "Figure caption for KEYEXPANSION of AES-256",
//     "category": "Diagram"
//   },
//   {
//     "label": "50:13140-13165",
//     "description": "Section header for InvMixColumns() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "51:13167-13490",
//     "description": "Definition of INVMIXCOLUMNS() as the inverse of MIXCOLUMNS() using a different fixed matrix",
//     "category": "Definition"
//   },
//   {
//     "label": "52:13492-13975",
//     "description": "Matrix representation of the INVMIXCOLUMNS() transformation",
//     "category": "Algorithm"
//   },
//   {
//     "label": "53:13977-14815",
//     "description": "Expanded definition of individual output bytes in the INVMIXCOLUMNS() transformation",
//     "category": "Algorithm"
//   },
//   {
//     "label": "54:14817-14851",
//     "description": "Section header for the inverse of ADDROUNDKEY() transformation",
//     "category": "Navigation"
//   },
//   {
//     "label": "55:14853-14915",
//     "description": "Statement that ADDROUNDKEY() is its own inverse",
//     "category": "Definition"
//   },
//   {
//     "label": "56:14917-14940",
//     "description": "Section header for EQINVCIPHER() function",
//     "category": "Navigation"
//   },
//   {
//     "label": "57:14942-15439",
//     "description": "Explanation of EQINVCIPHER() as an alternative specification of the inverse cipher",
//     "category": "Definition"
//   },
//   {
//     "label": "58:15441-15700",
//     "description": "Introduction to the pseudocode for EQINVCIPHER() and KEYEXPANSIONEIC()",
//     "category": "Navigation"
//   },
//   {
//     "label": "59:15702-16254",
//     "description": "Pseudocode implementation of the EQINVCIPHER() function",
//     "category": "Algorithm"
//   },
//   {
//     "label": "60:16256-17040",
//     "description": "Pseudocode implementation of the KEYEXPANSIONEIC() function",
//     "category": "Algorithm"
//   },
//   {
//     "label": "61:17042-17335",
//     "description": "Explanation of how the modified key schedule in KEYEXPANSIONEIC() differs from the original",
//     "category": "Elaboration"
//   }
// ]
// ```

// %%
console.log(JSON.stringify(output, null, 2));
// Out:
// [
//   {
//     "label": "0:0-18",
//     "description": "Section header for the preprocessing section",
//     "category": "Navigation"
//   },
//   {
//     "label": "1:20-205",
//     "description": "Overview of the three preprocessing steps: padding the message, parsing the message, and setting the initial hash value",
//     "category": "Elaboration"
//   },
//   {
//     "label": "2:207-233",
//     "description": "Subsection header for padding the message",
//     "category": "Navigation"
//   },
//   {
//     "label": "3:235-544",
//     "description": "Explanation of the purpose of padding to ensure the message is a multiple of 512 or 1024 bits",
//     "category": "Intent"
//   },
//   {
//     "label": "4:546-582",
//     "description": "Subsubsection header for SHA-1, SHA-224 and SHA-256 padding",
//     "category": "Navigation"
//   },
//   {
//     "label": "5:584-1133",
//     "description": "Detailed algorithm for padding messages in SHA-1, SHA-224 and SHA-256, including the formula for calculating padding bits and an example",
//     "category": "Algorithm"
//   },
//   {
//     "label": "6:1135-1173",
//     "description": "Reference to an image showing padded message representation",
//     "category": "Diagram"
//   },
//   {
//     "label": "7:1175-1245",
//     "description": "Post-condition that the padded message length must be a multiple of 512 bits",
//     "category": "Ensure"
//   },
//   {
//     "label": "8:1247-1273",
//     "description": "Subsection header for parsing the message",
//     "category": "Navigation"
//   },
//   {
//     "label": "9:1275-1340",
//     "description": "Brief statement that the message and padding must be parsed into m-bit blocks",
//     "category": "Require"
//   },
//   {
//     "label": "10:1342-1378",
//     "description": "Subsubsection header for SHA-1, SHA-224 and SHA-256 parsing",
//     "category": "Navigation"
//   },
//   {
//     "label": "11:1380-1726",
//     "description": "Specification of how messages are parsed into 512-bit blocks for SHA-1, SHA-224 and SHA-256, and how these blocks are represented as 32-bit words",
//     "category": "Algorithm"
//   },
//   {
//     "label": "12:1728-1777",
//     "description": "Subsection header for setting the initial hash value",
//     "category": "Navigation"
//   },
//   {
//     "label": "13:1779-1975",
//     "description": "Explanation that an initial hash value must be set before hash computation begins",
//     "category": "Require"
//   },
//   {
//     "label": "14:1977-1992",
//     "description": "Subsubsection header for SHA-1 initial hash value",
//     "category": "Navigation"
//   },
//   {
//     "label": "15:1994-2317",
//     "description": "Specification of the five 32-bit words that constitute the initial hash value for SHA-1, given in hexadecimal",
//     "category": "Parameter"
//   },
//   {
//     "label": "16:2319-2346",
//     "description": "Section header for secure hash algorithms",
//     "category": "Navigation"
//   },
//   {
//     "label": "17:2348-2848",
//     "description": "Explanation of why algorithms are not presented in ascending order of size, noting relationships between SHA-256/SHA-224 and SHA-512/SHA-384/SHA-512/224/SHA-512/256",
//     "category": "Elaboration"
//   },
//   {
//     "label": "18:2850-3114",
//     "description": "Statement that alternate computation methods yielding identical results are acceptable implementations",
//     "category": "Preference"
//   },
//   {
//     "label": "19:3116-3128",
//     "description": "Subsection header for SHA-1",
//     "category": "Navigation"
//   },
//   {
//     "label": "20:3130-3438",
//     "description": "Overview of SHA-1 algorithm, including input constraints, components used, and output size",
//     "category": "Definition"
//   },
//   {
//     "label": "21:3440-3983",
//     "description": "Definition of the variables and notation used in the SHA-1 algorithm, including message schedule words, working variables, hash value words, and temporary word",
//     "category": "Definition"
//   },
//   {
//     "label": "22:3985-4014",
//     "description": "Subsubsection header for SHA-1 preprocessing",
//     "category": "Navigation"
//   },
//   {
//     "label": "23:4016-4148",
//     "description": "Two-step process for SHA-1 preprocessing: setting initial hash value and padding/parsing the message",
//     "category": "Algorithm"
//   },
//   {
//     "label": "24:4150-4182",
//     "description": "Subsubsection header for SHA-1 hash computation",
//     "category": "Navigation"
//   },
//   {
//     "label": "25:4184-4345",
//     "description": "Reference to previously defined functions and constants used in SHA-1, and specification that addition is performed modulo 2^32",
//     "category": "Elaboration"
//   },
//   {
//     "label": "26:4347-4453",
//     "description": "Introduction to the message block processing steps for SHA-1",
//     "category": "Elaboration"
//   },
//   {
//     "label": "27:4455-5510",
//     "description": "Detailed algorithm for SHA-1 hash computation, including message schedule preparation, working variable initialization, the main processing loop, and intermediate hash value computation",
//     "category": "Algorithm"
//   },
//   {
//     "label": "28:5512-5736",
//     "description": "Final step of SHA-1 algorithm showing how the 160-bit message digest is formed from the final hash value",
//     "category": "Algorithm"
//   }
// ]

// %%
console.log("SEGMENTS LENGTH", lhsSegments.length);
console.log("LLM OUTPUT LENGTH", output.length);

const counter = {};
for (const {text, label} of lhsSegments) {
  counter[label] = 0;
}
for (const {label, description, category} of output) {
  if (label in counter) {
    if (counter[label] !== 0) {
      console.log("ERROR: LABEL ALREADY EXISTS IN OUTPUT", label, counter[label]);
    }
    counter[label] += 1;
  } else {
    console.log("ERROR: LABEL NOT FOUND IN LHS TEXT", label);
  } 
}
for (const {text, label} of lhsSegments) {
  if (counter[label] !== 1) {
    console.log("ERROR: LABEL NOT FOUND IN OUTPUT", label, counter[label]);
  }
}
console.log("DONE: If no errors above, then everything is ok.");
// Out:
// SEGMENTS LENGTH 29
// LLM OUTPUT LENGTH 29
// DONE: If no errors above, then everything is ok.

// %%
const annotations = []
for (const {label, description, category} of output) {
  const match = label.match(/(\d+):(\d+)-(\d+)/);
  const start = parseInt(match[2]);
  const stop = parseInt(match[3]);
  const text = lhsText.substring(start,stop);
  annotations.push({start, stop, category, description, text});
  console.log("LABEL", label);
  console.log("CATEGORY", category);
  console.log("DESCRIPTION", description);
  console.log("TEXT", text);
  console.log("");
}
// Out:
// LABEL 0:0-18
// CATEGORY Navigation
// DESCRIPTION Section header for the preprocessing section
// TEXT # 5. PREPROCESSING
//
// LABEL 1:20-205
// CATEGORY Elaboration
// DESCRIPTION Overview of the three preprocessing steps: padding the message, parsing the message, and setting the initial hash value
// TEXT Preprocessing consists of three steps: padding the message, $M$ (Sec. 5.1), parsing the message into message blocks (Sec. 5.2), and setting the initial hash value, $H^{(0)}$ (Sec. 5.3).
//
// LABEL 2:207-233
// CATEGORY Navigation
// DESCRIPTION Subsection header for padding the message
// TEXT ## 5.1 Padding the Message
//
// LABEL 3:235-544
// CATEGORY Intent
// DESCRIPTION Explanation of the purpose of padding to ensure the message is a multiple of 512 or 1024 bits
// TEXT The purpose of this padding is to ensure that the padded message is a multiple of 512 or 1024 bits, depending on the algorithm. Padding can be inserted before hash computation begins on a message, or at any other time during the hash computation prior to processing the block(s) that will contain the padding.
//
// LABEL 4:546-582
// CATEGORY Navigation
// DESCRIPTION Subsubsection header for SHA-1, SHA-224 and SHA-256 padding
// TEXT ### 5.1.1 SHA-1, SHA-224 and SHA-256
//
// LABEL 5:584-1133
// CATEGORY Algorithm
// DESCRIPTION Detailed algorithm for padding messages in SHA-1, SHA-224 and SHA-256, including the formula for calculating padding bits and an example
// TEXT Suppose that the length of the message, $M$, is $\ell$ bits. Append the bit "1" to the end of the message, followed by $k$ zero bits, where $k$ is the smallest, non-negative solution to the equation $\ell+1+k \equiv 448 \bmod 512$. Then append the 64-bit block that is equal to the number $\ell$ expressed using a binary representation. For example, the (8-bit ASCII) message "abc" has length $8 \times 3=24$, so the message is padded with a one bit, then $448-(24+1)=423$ zero bits, and then the message length, to become the 512-bit padded message
//
// LABEL 6:1135-1173
// CATEGORY Diagram
// DESCRIPTION Reference to an image showing padded message representation
// TEXT [IMAGE: Padded message representation]
//
// LABEL 7:1175-1245
// CATEGORY Ensure
// DESCRIPTION Post-condition that the padded message length must be a multiple of 512 bits
// TEXT The length of the padded message should now be a multiple of 512 bits.
//
// LABEL 8:1247-1273
// CATEGORY Navigation
// DESCRIPTION Subsection header for parsing the message
// TEXT ## 5.2 Parsing the Message
//
// LABEL 9:1275-1340
// CATEGORY Require
// DESCRIPTION Brief statement that the message and padding must be parsed into m-bit blocks
// TEXT The message and its padding must be parsed into $N m$-bit blocks.
//
// LABEL 10:1342-1378
// CATEGORY Navigation
// DESCRIPTION Subsubsection header for SHA-1, SHA-224 and SHA-256 parsing
// TEXT ### 5.2.1 SHA-1, SHA-224 and SHA-256
//
// LABEL 11:1380-1726
// CATEGORY Algorithm
// DESCRIPTION Specification of how messages are parsed into 512-bit blocks for SHA-1, SHA-224 and SHA-256, and how these blocks are represented as 32-bit words
// TEXT For SHA-1, SHA-224 and SHA-256, the message and its padding are parsed into $N$ 512-bit blocks, $M^{(1)}, M^{(2)}, \ldots, M^{(N)}$. Since the 512 bits of the input block may be expressed as sixteen 32-bit words, the first 32 bits of message block $i$ are denoted $M_{0}^{(i)}$, the next 32 bits are $M_{1}^{(i)}$, and so on up to $M_{15}^{(i)}$.
//
// LABEL 12:1728-1777
// CATEGORY Navigation
// DESCRIPTION Subsection header for setting the initial hash value
// TEXT ## 5.3 Setting the Initial Hash Value ($H^{(0)}$)
//
// LABEL 13:1779-1975
// CATEGORY Require
// DESCRIPTION Explanation that an initial hash value must be set before hash computation begins
// TEXT Before hash computation begins for each of the secure hash algorithms, the initial hash value, $H^{(0)}$, must be set. The size and number of words in $H^{(0)}$ depends on the message digest size.
//
// LABEL 14:1977-1992
// CATEGORY Navigation
// DESCRIPTION Subsubsection header for SHA-1 initial hash value
// TEXT ### 5.3.1 SHA-1
//
// LABEL 15:1994-2317
// CATEGORY Parameter
// DESCRIPTION Specification of the five 32-bit words that constitute the initial hash value for SHA-1, given in hexadecimal
// TEXT For SHA-1, the initial hash value, $H^{(0)}$, shall consist of the following five 32-bit words, in hex:
// $$
// \begin{aligned}
// H_{0}^{(0)} &= 67452301 \\
// H_{1}^{(0)} &= \text{efcdab89} \\
// H_{2}^{(0)} &= 98\mathrm{badcfe} \\
// H_{3}^{(0)} &= 10325476 \\
// H_{4}^{(0)} &= \mathrm{c}3\mathrm{d}2\mathrm{e}1\mathrm{f0}
// \end{aligned}
// $$
//
// LABEL 16:2319-2346
// CATEGORY Navigation
// DESCRIPTION Section header for secure hash algorithms
// TEXT # 6. SECURE HASH ALGORITHMS
//
// LABEL 17:2348-2848
// CATEGORY Elaboration
// DESCRIPTION Explanation of why algorithms are not presented in ascending order of size, noting relationships between SHA-256/SHA-224 and SHA-512/SHA-384/SHA-512/224/SHA-512/256
// TEXT In the following sections, the hash algorithms are not described in ascending order of size. SHA-256 is described before SHA-224 because the specification for SHA-224 is identical to SHA-256, except that different initial hash values are used, and the final hash value is truncated to 224 bits for SHA-224. The same is true for SHA-512, SHA-384, SHA-512/224 and SHA-512/256, except that the final hash value is truncated to 224 bits for SHA-512/224, 256 bits for SHA$512/256$ or 384 bits for SHA-384.
//
// LABEL 18:2850-3114
// CATEGORY Preference
// DESCRIPTION Statement that alternate computation methods yielding identical results are acceptable implementations
// TEXT For each of the secure hash algorithms, there may exist alternate computation methods that yield identical results; one example is the alternative SHA-1 computation described in Sec. 6.1.3. Such alternate methods may be implemented in conformance to this standard.
//
// LABEL 19:3116-3128
// CATEGORY Navigation
// DESCRIPTION Subsection header for SHA-1
// TEXT ## 6.1 SHA-1
//
// LABEL 20:3130-3438
// CATEGORY Definition
// DESCRIPTION Overview of SHA-1 algorithm, including input constraints, components used, and output size
// TEXT SHA-1 may be used to hash a message, $M$, having a length of $\ell$ bits, where $0 \leq \ell < 2^{64}$. The algorithm uses 1) a message schedule of eighty 32-bit words, 2) five working variables of 32 bits each, and 3) a hash value of five 32-bit words. The final result of SHA-1 is a 160-bit message digest.
//
// LABEL 21:3440-3983
// CATEGORY Definition
// DESCRIPTION Definition of the variables and notation used in the SHA-1 algorithm, including message schedule words, working variables, hash value words, and temporary word
// TEXT The words of the message schedule are labeled $W_{0}, W_{1}, \ldots, W_{79}$. The five working variables are labeled $\boldsymbol{a}, \boldsymbol{b}, \boldsymbol{c}, \boldsymbol{d}$, and $\boldsymbol{e}$. The words of the hash value are labeled $H_{0}^{(i)}, H_{1}^{(i)}, \ldots, H_{4}^{(i)}$, which will hold the initial hash value, $H^{(0)}$, replaced by each successive intermediate hash value (after each message block is processed), $H^{(i)}$, and ending with the final hash value, $H^{(N)}$. SHA-1 also uses a single temporary word, $T$.
//
// LABEL 22:3985-4014
// CATEGORY Navigation
// DESCRIPTION Subsubsection header for SHA-1 preprocessing
// TEXT ### 6.1.1 SHA-1 Preprocessing
//
// LABEL 23:4016-4148
// CATEGORY Algorithm
// DESCRIPTION Two-step process for SHA-1 preprocessing: setting initial hash value and padding/parsing the message
// TEXT 1. Set the initial hash value, $H^{(0)}$, as specified in Sec. 5.3.1.
// 2. The message is padded and parsed as specified in Section 5.
//
// LABEL 24:4150-4182
// CATEGORY Navigation
// DESCRIPTION Subsubsection header for SHA-1 hash computation
// TEXT ### 6.1.2 SHA-1 Hash Computation
//
// LABEL 25:4184-4345
// CATEGORY Elaboration
// DESCRIPTION Reference to previously defined functions and constants used in SHA-1, and specification that addition is performed modulo 2^32
// TEXT The SHA-1 hash computation uses functions and constants previously defined in Sec. 4.1.1 and Sec. 4.2.1, respectively. Addition (+) is performed modulo $2^{32}$.
//
// LABEL 26:4347-4453
// CATEGORY Elaboration
// DESCRIPTION Introduction to the message block processing steps for SHA-1
// TEXT Each message block, $M^{(1)}, M^{(2)}, \ldots, M^{(N)}$, is processed in order, using the following steps:
//
// LABEL 27:4455-5510
// CATEGORY Algorithm
// DESCRIPTION Detailed algorithm for SHA-1 hash computation, including message schedule preparation, working variable initialization, the main processing loop, and intermediate hash value computation
// TEXT For $i=1$ to $N$:
// {
// 1. Prepare the message schedule, $\{W_{t}\}$:
//    $$W_{t}= \begin{cases}
//    M_{t}^{(i)} & 0 \leq t \leq 15 \\
//    ROTL^{1}(W_{t-3} \oplus W_{t-8} \oplus W_{t-14} \oplus W_{t-16}) & 16 \leq t \leq 79
//    \end{cases}$$
// 2. Initialize the five working variables, $\boldsymbol{a}, \boldsymbol{b}, \boldsymbol{c}, \boldsymbol{d}$, and $\boldsymbol{e}$, with the $(i-1)^{st}$ hash value:
//    $$\begin{aligned}
//    a &= H_{0}^{(i-1)} \\
//    b &= H_{1}^{(i-1)} \\
//    c &= H_{2}^{(i-1)} \\
//    d &= H_{3}^{(i-1)} \\
//    e &= H_{4}^{(i-1)}
//    \end{aligned}$$
// 3. For $t=0$ to 79:
//    {
//    $$\begin{aligned}
//    T &= ROTL^{5}(a) + f_{t}(b, c, d) + e + K_{t} + W_{t} \\
//    e &= d \\
//    d &= c \\
//    c &= ROTL^{30}(b) \\
//    b &= a \\
//    a &= T
//    \end{aligned}$$
//    }
// 4. Compute the $i^{th}$ intermediate hash value $H^{(i)}$:
//    $$\begin{aligned}
//    H_{0}^{(i)} &= a + H_{0}^{(i-1)} \\
//    H_{1}^{(i)} &= b + H_{1}^{(i-1)} \\
//    H_{2}^{(i)} &= c + H_{2}^{(i-1)} \\
//    H_{3}^{(i)} &= d + H_{3}^{(i-1)} \\
//    H_{4}^{(i)} &= e + H_{4}^{(i-1)}
//    \end{aligned}$$
// }
//
// LABEL 28:5512-5736
// CATEGORY Algorithm
// DESCRIPTION Final step of SHA-1 algorithm showing how the 160-bit message digest is formed from the final hash value
// TEXT After repeating steps one through four a total of $N$ times (i.e., after processing $M^{(N)}$), the resulting 160-bit message digest of the message, $M$, is
// $$H_{0}^{(N)}||H_{1}^{(N)}||H_{2}^{(N)}||H_{3}^{(N)}||H_{4}^{(N)}$$

// %%
console.log(JSON.stringify(annotations, null, 2));
// Out:
// [
//   {
//     "start": 0,
//     "stop": 18,
//     "category": "Navigation",
//     "description": "Section header for the preprocessing section",
//     "text": "# 5. PREPROCESSING"
//   },
//   {
//     "start": 20,
//     "stop": 205,
//     "category": "Elaboration",
//     "description": "Overview of the three preprocessing steps: padding the message, parsing the message, and setting the initial hash value",
//     "text": "Preprocessing consists of three steps: padding the message, $M$ (Sec. 5.1), parsing the message into message blocks (Sec. 5.2), and setting the initial hash value, $H^{(0)}$ (Sec. 5.3)."
//   },
//   {
//     "start": 207,
//     "stop": 233,
//     "category": "Navigation",
//     "description": "Subsection header for padding the message",
//     "text": "## 5.1 Padding the Message"
//   },
//   {
//     "start": 235,
//     "stop": 544,
//     "category": "Intent",
//     "description": "Explanation of the purpose of padding to ensure the message is a multiple of 512 or 1024 bits",
//     "text": "The purpose of this padding is to ensure that the padded message is a multiple of 512 or 1024 bits, depending on the algorithm. Padding can be inserted before hash computation begins on a message, or at any other time during the hash computation prior to processing the block(s) that will contain the padding."
//   },
//   {
//     "start": 546,
//     "stop": 582,
//     "category": "Navigation",
//     "description": "Subsubsection header for SHA-1, SHA-224 and SHA-256 padding",
//     "text": "### 5.1.1 SHA-1, SHA-224 and SHA-256"
//   },
//   {
//     "start": 584,
//     "stop": 1133,
//     "category": "Algorithm",
//     "description": "Detailed algorithm for padding messages in SHA-1, SHA-224 and SHA-256, including the formula for calculating padding bits and an example",
//     "text": "Suppose that the length of the message, $M$, is $\\ell$ bits. Append the bit \"1\" to the end of the message, followed by $k$ zero bits, where $k$ is the smallest, non-negative solution to the equation $\\ell+1+k \\equiv 448 \\bmod 512$. Then append the 64-bit block that is equal to the number $\\ell$ expressed using a binary representation. For example, the (8-bit ASCII) message \"abc\" has length $8 \\times 3=24$, so the message is padded with a one bit, then $448-(24+1)=423$ zero bits, and then the message length, to become the 512-bit padded message"
//   },
//   {
//     "start": 1135,
//     "stop": 1173,
//     "category": "Diagram",
//     "description": "Reference to an image showing padded message representation",
//     "text": "[IMAGE: Padded message representation]"
//   },
//   {
//     "start": 1175,
//     "stop": 1245,
//     "category": "Ensure",
//     "description": "Post-condition that the padded message length must be a multiple of 512 bits",
//     "text": "The length of the padded message should now be a multiple of 512 bits."
//   },
//   {
//     "start": 1247,
//     "stop": 1273,
//     "category": "Navigation",
//     "description": "Subsection header for parsing the message",
//     "text": "## 5.2 Parsing the Message"
//   },
//   {
//     "start": 1275,
//     "stop": 1340,
//     "category": "Require",
//     "description": "Brief statement that the message and padding must be parsed into m-bit blocks",
//     "text": "The message and its padding must be parsed into $N m$-bit blocks."
//   },
//   {
//     "start": 1342,
//     "stop": 1378,
//     "category": "Navigation",
//     "description": "Subsubsection header for SHA-1, SHA-224 and SHA-256 parsing",
//     "text": "### 5.2.1 SHA-1, SHA-224 and SHA-256"
//   },
//   {
//     "start": 1380,
//     "stop": 1726,
//     "category": "Algorithm",
//     "description": "Specification of how messages are parsed into 512-bit blocks for SHA-1, SHA-224 and SHA-256, and how these blocks are represented as 32-bit words",
//     "text": "For SHA-1, SHA-224 and SHA-256, the message and its padding are parsed into $N$ 512-bit blocks, $M^{(1)}, M^{(2)}, \\ldots, M^{(N)}$. Since the 512 bits of the input block may be expressed as sixteen 32-bit words, the first 32 bits of message block $i$ are denoted $M_{0}^{(i)}$, the next 32 bits are $M_{1}^{(i)}$, and so on up to $M_{15}^{(i)}$."
//   },
//   {
//     "start": 1728,
//     "stop": 1777,
//     "category": "Navigation",
//     "description": "Subsection header for setting the initial hash value",
//     "text": "## 5.3 Setting the Initial Hash Value ($H^{(0)}$)"
//   },
//   {
//     "start": 1779,
//     "stop": 1975,
//     "category": "Require",
//     "description": "Explanation that an initial hash value must be set before hash computation begins",
//     "text": "Before hash computation begins for each of the secure hash algorithms, the initial hash value, $H^{(0)}$, must be set. The size and number of words in $H^{(0)}$ depends on the message digest size."
//   },
//   {
//     "start": 1977,
//     "stop": 1992,
//     "category": "Navigation",
//     "description": "Subsubsection header for SHA-1 initial hash value",
//     "text": "### 5.3.1 SHA-1"
//   },
//   {
//     "start": 1994,
//     "stop": 2317,
//     "category": "Parameter",
//     "description": "Specification of the five 32-bit words that constitute the initial hash value for SHA-1, given in hexadecimal",
//     "text": "For SHA-1, the initial hash value, $H^{(0)}$, shall consist of the following five 32-bit words, in hex:\n$$\n\\begin{aligned}\nH_{0}^{(0)} &= 67452301 \\\\\nH_{1}^{(0)} &= \\text{efcdab89} \\\\\nH_{2}^{(0)} &= 98\\mathrm{badcfe} \\\\\nH_{3}^{(0)} &= 10325476 \\\\\nH_{4}^{(0)} &= \\mathrm{c}3\\mathrm{d}2\\mathrm{e}1\\mathrm{f0}\n\\end{aligned}\n$$"
//   },
//   {
//     "start": 2319,
//     "stop": 2346,
//     "category": "Navigation",
//     "description": "Section header for secure hash algorithms",
//     "text": "# 6. SECURE HASH ALGORITHMS"
//   },
//   {
//     "start": 2348,
//     "stop": 2848,
//     "category": "Elaboration",
//     "description": "Explanation of why algorithms are not presented in ascending order of size, noting relationships between SHA-256/SHA-224 and SHA-512/SHA-384/SHA-512/224/SHA-512/256",
//     "text": "In the following sections, the hash algorithms are not described in ascending order of size. SHA-256 is described before SHA-224 because the specification for SHA-224 is identical to SHA-256, except that different initial hash values are used, and the final hash value is truncated to 224 bits for SHA-224. The same is true for SHA-512, SHA-384, SHA-512/224 and SHA-512/256, except that the final hash value is truncated to 224 bits for SHA-512/224, 256 bits for SHA$512/256$ or 384 bits for SHA-384."
//   },
//   {
//     "start": 2850,
//     "stop": 3114,
//     "category": "Preference",
//     "description": "Statement that alternate computation methods yielding identical results are acceptable implementations",
//     "text": "For each of the secure hash algorithms, there may exist alternate computation methods that yield identical results; one example is the alternative SHA-1 computation described in Sec. 6.1.3. Such alternate methods may be implemented in conformance to this standard."
//   },
//   {
//     "start": 3116,
//     "stop": 3128,
//     "category": "Navigation",
//     "description": "Subsection header for SHA-1",
//     "text": "## 6.1 SHA-1"
//   },
//   {
//     "start": 3130,
//     "stop": 3438,
//     "category": "Definition",
//     "description": "Overview of SHA-1 algorithm, including input constraints, components used, and output size",
//     "text": "SHA-1 may be used to hash a message, $M$, having a length of $\\ell$ bits, where $0 \\leq \\ell < 2^{64}$. The algorithm uses 1) a message schedule of eighty 32-bit words, 2) five working variables of 32 bits each, and 3) a hash value of five 32-bit words. The final result of SHA-1 is a 160-bit message digest."
//   },
//   {
//     "start": 3440,
//     "stop": 3983,
//     "category": "Definition",
//     "description": "Definition of the variables and notation used in the SHA-1 algorithm, including message schedule words, working variables, hash value words, and temporary word",
//     "text": "The words of the message schedule are labeled $W_{0}, W_{1}, \\ldots, W_{79}$. The five working variables are labeled $\\boldsymbol{a}, \\boldsymbol{b}, \\boldsymbol{c}, \\boldsymbol{d}$, and $\\boldsymbol{e}$. The words of the hash value are labeled $H_{0}^{(i)}, H_{1}^{(i)}, \\ldots, H_{4}^{(i)}$, which will hold the initial hash value, $H^{(0)}$, replaced by each successive intermediate hash value (after each message block is processed), $H^{(i)}$, and ending with the final hash value, $H^{(N)}$. SHA-1 also uses a single temporary word, $T$."
//   },
//   {
//     "start": 3985,
//     "stop": 4014,
//     "category": "Navigation",
//     "description": "Subsubsection header for SHA-1 preprocessing",
//     "text": "### 6.1.1 SHA-1 Preprocessing"
//   },
//   {
//     "start": 4016,
//     "stop": 4148,
//     "category": "Algorithm",
//     "description": "Two-step process for SHA-1 preprocessing: setting initial hash value and padding/parsing the message",
//     "text": "1. Set the initial hash value, $H^{(0)}$, as specified in Sec. 5.3.1.\n2. The message is padded and parsed as specified in Section 5."
//   },
//   {
//     "start": 4150,
//     "stop": 4182,
//     "category": "Navigation",
//     "description": "Subsubsection header for SHA-1 hash computation",
//     "text": "### 6.1.2 SHA-1 Hash Computation"
//   },
//   {
//     "start": 4184,
//     "stop": 4345,
//     "category": "Elaboration",
//     "description": "Reference to previously defined functions and constants used in SHA-1, and specification that addition is performed modulo 2^32",
//     "text": "The SHA-1 hash computation uses functions and constants previously defined in Sec. 4.1.1 and Sec. 4.2.1, respectively. Addition (+) is performed modulo $2^{32}$."
//   },
//   {
//     "start": 4347,
//     "stop": 4453,
//     "category": "Elaboration",
//     "description": "Introduction to the message block processing steps for SHA-1",
//     "text": "Each message block, $M^{(1)}, M^{(2)}, \\ldots, M^{(N)}$, is processed in order, using the following steps:"
//   },
//   {
//     "start": 4455,
//     "stop": 5510,
//     "category": "Algorithm",
//     "description": "Detailed algorithm for SHA-1 hash computation, including message schedule preparation, working variable initialization, the main processing loop, and intermediate hash value computation",
//     "text": "For $i=1$ to $N$:\n{\n1. Prepare the message schedule, $\\{W_{t}\\}$:\n   $$W_{t}= \\begin{cases}\n   M_{t}^{(i)} & 0 \\leq t \\leq 15 \\\\\n   ROTL^{1}(W_{t-3} \\oplus W_{t-8} \\oplus W_{t-14} \\oplus W_{t-16}) & 16 \\leq t \\leq 79\n   \\end{cases}$$\n2. Initialize the five working variables, $\\boldsymbol{a}, \\boldsymbol{b}, \\boldsymbol{c}, \\boldsymbol{d}$, and $\\boldsymbol{e}$, with the $(i-1)^{st}$ hash value:\n   $$\\begin{aligned}\n   a &= H_{0}^{(i-1)} \\\\\n   b &= H_{1}^{(i-1)} \\\\\n   c &= H_{2}^{(i-1)} \\\\\n   d &= H_{3}^{(i-1)} \\\\\n   e &= H_{4}^{(i-1)}\n   \\end{aligned}$$\n3. For $t=0$ to 79:\n   {\n   $$\\begin{aligned}\n   T &= ROTL^{5}(a) + f_{t}(b, c, d) + e + K_{t} + W_{t} \\\\\n   e &= d \\\\\n   d &= c \\\\\n   c &= ROTL^{30}(b) \\\\\n   b &= a \\\\\n   a &= T\n   \\end{aligned}$$\n   }\n4. Compute the $i^{th}$ intermediate hash value $H^{(i)}$:\n   $$\\begin{aligned}\n   H_{0}^{(i)} &= a + H_{0}^{(i-1)} \\\\\n   H_{1}^{(i)} &= b + H_{1}^{(i-1)} \\\\\n   H_{2}^{(i)} &= c + H_{2}^{(i-1)} \\\\\n   H_{3}^{(i)} &= d + H_{3}^{(i-1)} \\\\\n   H_{4}^{(i)} &= e + H_{4}^{(i-1)}\n   \\end{aligned}$$\n}"
//   },
//   {
//     "start": 5512,
//     "stop": 5736,
//     "category": "Algorithm",
//     "description": "Final step of SHA-1 algorithm showing how the 160-bit message digest is formed from the final hash value",
//     "text": "After repeating steps one through four a total of $N$ times (i.e., after processing $M^{(N)}$), the resulting 160-bit message digest of the message, $M$, is\n$$H_{0}^{(N)}||H_{1}^{(N)}||H_{2}^{(N)}||H_{3}^{(N)}||H_{4}^{(N)}$$"
//   }
// ]

// %%
const queryInput = "Can you rewrite the following prompt so that it is clearer?";
const queryOutput = await chain.invoke({ messages: [ 
    new SystemMessage(queryInput),
    new HumanMessage(PROMPT)
]});
console.log(queryOutput.content);
// Out:
// I'll rewrite the prompt to make it clearer:
//
// # Semantic Classification of Cryptographic Standards
//
// ## Your Role
// You are an expert in analyzing cryptographic standards written in natural language.
//
// ## Input Format
// You will receive sections from a FIPS publication describing a cryptographic algorithm. The text will be:
// - In markdown format with LaTeX mathematical formulas
// - Divided into consecutive labeled segments
// - The complete set of segments forms what we'll call "the full text"
//
// ## Your Task
// For each segment, analyze its content in context of the full text and classify it into exactly one of these categories:
//
// 1. **Preamble**: Document front matter in markdown
// 2. **Navigation**: Headers, outlines, or internal references
// 3. **Algorithm**: Formal algorithm or function description (like pseudocode)
// 4. **Parameter**: Formal definition of data parameters used in algorithms
// 5. **Definition**: Formal definition of terms or concepts
// 6. **Elaboration**: Text explaining algorithms, parameters, or definitions
// 7. **Diagram**: Visual explanations of algorithms, parameters, or definitions
// 8. **Intent**: Explanation of design rationale
// 9. **Require**: Mandatory pre-conditions for algorithms
// 10. **Ensure**: Mandatory post-conditions of algorithms
// 11. **Preference**: Non-mandatory recommendations
// 12. **Example**: Specific algorithm applications
//
// ## Output Format
// Provide a JSON array where each object contains:
// - `"label"`: The segment's original label (exactly as provided)
// - `"description"`: A concise summary of the segment's content
// - `"category"`: The single most appropriate category from the list above
//
// Please analyze all segments in the provided list without omitting any.
