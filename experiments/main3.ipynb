// %% [markdown]
// # Semantic Categories

// %%
import { START, END, StateGraph, MemorySaver } from "@langchain/langgraph";
import { SystemMessage, HumanMessage } from "@langchain/core/messages";
import { JsonOutputParser } from "@langchain/core/output_parsers";
import { readFileSync } from 'node:fs';


import { EXPERIMENTS_DIR, SERVER_DATA_DIR } from '../server/src/util/fileUtils.ts';
import { getNotebookLogger } from '../server/src/Logger.ts';
import { StateInfo, responseContent } from '../server/src/agents/agent.ts';
import { modelNode } from '../server/src/agents/nodes/modelNode.ts';

// Define a new graph
const workflow = new StateGraph(StateInfo)
  .addNode("model", modelNode)
  .addEdge(START, "model")
  .addEdge("model", END);

// Add memory
const memory = new MemorySaver();
const graph = workflow.compile({ checkpointer: memory });

const logger = getNotebookLogger();
const userUUID: string = "0";
const config = { configurable: { thread_id: userUUID } };
const lhsText = readFileSync(`${SERVER_DATA_DIR}/SHA-1/selected-text.txt`, 'utf-8');
const PROMPT = readFileSync(`${EXPERIMENTS_DIR}/annotateNodePromptCategories3.txt`, 'utf-8');

var userInput = lhsText;
var output = await graph.invoke({ messages: [
  new SystemMessage(PROMPT),
  new HumanMessage(userInput)
], logger: logger}, config);
logger.info(responseContent(output));
// Out:
// Sending messages to LLM.
// Received response from LLM.
// LLM usage: 2809 input tokens, 2700 output tokens
// ```json
// [
//   {
//     "description": "Section header for preprocessing steps in SHA-1",
//     "text": "\\section*{5. PREPROCESSING}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Overview of the three preprocessing steps for SHA-1",
//     "text": "Preprocessing consists of three steps: padding the message, \\(M\\) (Sec. 5.1), parsing the message into",
//     "label": "Definitions"
//   },
//   {
//     "description": "Subsection header for message padding",
//     "text": "\\subsection*{5.1 Padding the Message}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Explanation of the purpose of padding in SHA-1",
//     "text": "The purpose of this padding is to ensure that the padded message is a multiple of 512 or 1024 bits, de",
//     "label": "Intent"
//   },
//   {
//     "description": "Subsection header for SHA-1, SHA-224 and SHA-256 padding",
//     "text": "\\subsection*{5.1.1 SHA-1, SHA-224 and SHA-256}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Detailed algorithm for padding messages in SHA-1",
//     "text": "Suppose that the length of the message, \\(M\\), is \\(\\ell\\) bits. Append the bit " 1 " to the end of the",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Image showing an example of padded message",
//     "text": "\\includegraphics[max width=\\textwidth, center]{2025_01_07_9c328d09069db93254c0g-18}",
//     "label": "Examples"
//   },
//   {
//     "description": "Requirement that padded message length must be a multiple of 512 bits",
//     "text": "The length of the padded message should now be a multiple of 512 bits.",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsection header for message parsing",
//     "text": "\\subsection*{5.2 Parsing the Message}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Brief description of message parsing requirement",
//     "text": "The message and its padding must be parsed into \\(N m\\)-bit blocks.",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsection header for SHA-1, SHA-224 and SHA-256 parsing",
//     "text": "\\subsection*{5.2.1 SHA-1, SHA-224 and SHA-256}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Detailed specification of how messages are parsed into blocks for SHA-1",
//     "text": "For SHA-1, SHA-224 and SHA-256, the message and its padding are parsed into \\(N\\) 512-bit blocks, \\(M^",
//     "label": "Definitions"
//   },
//   {
//     "description": "Subsection header for initial hash value",
//     "text": "\\subsection*{5.3 Setting the Initial Hash Value ( \\(H^{(0)}\\) )}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Explanation of the initial hash value requirement",
//     "text": "Before hash computation begins for each of the secure hash algorithms, the initial hash value, \\(H^{(0)",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsection header for SHA-1 initial hash value",
//     "text": "\\subsection*{5.3.1 SHA-1}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Specification of the five 32-bit words that form the initial hash value for SHA-1",
//     "text": "For SHA-1, the initial hash value, \\(H^{(0)}\\), shall consist of the following five 32-bit words, in h",
//     "label": "Definitions"
//   },
//   {
//     "description": "Mathematical representation of the five initial hash values for SHA-1",
//     "text": "\\[\n\\begin{aligned}\nH_{0}^{(0)} & =67452301 \\\\\nH_{1}^{(0)} & =\\text { efcdab89 } \\\\\nH_{2}^{(0)} & =",
//     "label": "Definitions"
//   },
//   {
//     "description": "Section header for secure hash algorithms",
//     "text": "\\section*{6. SECURE HASH ALGORITHMS}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Explanation of the organization of hash algorithm descriptions in the document",
//     "text": "In the following sections, the hash algorithms are not described in ascending order of size. SHA256 is ",
//     "label": "Elaborations"
//   },
//   {
//     "description": "Statement allowing alternate computation methods that yield identical results",
//     "text": "For each of the secure hash algorithms, there may exist alternate computation methods that yield ident",
//     "label": "Preferences"
//   },
//   {
//     "description": "Subsection header for SHA-1",
//     "text": "\\subsection*{6.1 SHA-1}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Overview of SHA-1 algorithm characteristics and components",
//     "text": "SHA-1 may be used to hash a message, \\(M\\), having a length of \\(\\ell\\) bits, where \\(0 \\leq \\ell<2^{64",
//     "label": "Definitions"
//   },
//   {
//     "description": "Definition of variables and components used in SHA-1 computation",
//     "text": "The words of the message schedule are labeled \\(W_{0}, W_{1}, \\ldots, W_{79}\\). The five working variab",
//     "label": "Definitions"
//   },
//   {
//     "description": "Subsection header for SHA-1 preprocessing",
//     "text": "\\subsection*{6.1.1 SHA-1 Preprocessing}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Enumerated steps for SHA-1 preprocessing",
//     "text": "\\begin{enumerate}\n  \\item Set the initial hash value, \\(H^{(0)}\\), as specified in Sec. 5.3.1.\n  \\item",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Subsection header for SHA-1 hash computation",
//     "text": "\\subsection*{6.1.2 SHA-1 Hash Computation}",
//     "label": "Boilerplate"
//   },
//   {
//     "description": "Introduction to SHA-1 hash computation process",
//     "text": "The SHA-1 hash computation uses functions and constants previously defined in Sec. 4.1.1 and Sec. 4.2.",
//     "label": "Elaborations"
//   },
//   {
//     "description": "Beginning of the detailed SHA-1 hash computation algorithm",
//     "text": "Each message block, \\(M^{(1)}, M^{(2)}, \\ldots, M^{(N)}\\), is processed in order, using the following ",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Loop structure for processing message blocks in SHA-1",
//     "text": "For \\(i=1\\) to \\(N\\) :\\\\\n\\{\n\\begin{enumerate}\n  \\item Prepare the message schedule, \\(\\left\\{W_{t}\\r",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Formula for preparing the message schedule in SHA-1",
//     "text": "W_{t}= \\begin{cases}M_{t}^{(i)} & 0 \\leq t \\leq 15 \\\\ R O T L^{1}\\left(W_{t-3} \\oplus W_{t-8} \\oplus",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Initialization of working variables in SHA-1",
//     "text": "  \\item Initialize the five working variables, \\(\\boldsymbol{a}, \\boldsymbol{b}, \\boldsymbol{c}, \\bolds",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Formulas for initializing working variables in SHA-1",
//     "text": "\\[\n\\begin{aligned}\n& a=H_{0}^{(i-1)} \\\\\n& b=H_{1}^{(i-1)} \\\\\n& c=H_{2}^{(i-1)} \\\\\n& d=H_{3}^{(i-1",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Main processing loop for each message block in SHA-1",
//     "text": "  \\item For \\(t=0\\) to 79 :\\\\\n\\{\n\\[\n\\begin{aligned}\n& T=R O T L^{5}(a)+f_{t}(b, c, d)+e+K_{t}+W_{t",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Computation of intermediate hash values in SHA-1",
//     "text": "  \\item Compute the \\(i^{\\text {th }}\\) intermediate hash value \\(H^{(i)}\\) :\n\\[\n\\begin{aligned}\n& H_",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Final step to produce the 160-bit message digest in SHA-1",
//     "text": "After repeating steps one through four a total of \\(N\\) times (i.e., after processing \\(M^{(N)}\\) ), t",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Formula showing the concatenation of hash values to form the final message digest",
//     "text": "\\[\nH_{0}^{(N)}\\left\\|H_{1}^{(N)}\\right\\| H_{2}^{(N)}\\left\\|H_{3}^{(N)}\\right\\| H_{4}^{(N)}\n\\]",
//     "label": "Algorithms"
//   }
// ]
// ```

// %%
userInput = "Can you rewrite the prompt that I sent earlier so that it works on any algorithm (besides SHA-1) from any FIPS specification?";
output = await graph.invoke({ messages: [ new HumanMessage(userInput) ], logger: logger}, config);
logger.info(responseContent(output));
// Out:
// Sending messages to LLM.
// Received response from LLM.
// LLM usage: 5513 input tokens, 372 output tokens
// # Semantic Decomposition of Cryptographic Standards
//
// You are an expert in semantic decomposition of cryptographic standards written in natural language. You will be provided with a section from a FIPS publication that specifies a cryptographic algorithm. This text is written in LaTeX format, and is already decomposed into multi-line segments which are separated by new-lines.
//
// Your task is to label each segment with one of the following categories:
//
// - Boilerplate: LaTeX preamble code that does not contain semantic content, e.g. section headers.
// - Intent: Motivation for how the algorithm is designed or explanations of its purpose
// - Definitions: Formal definitions of algorithm components, transformations, or parameters
// - Elaborations: Additional descriptions or clarifications of existing definitions
// - Assumptions: What is assumed about the inputs or use cases of the algorithm
// - Requirements: What is required about the outputs or behaviors of the algorithm
// - Preferences: Non-mandatory recommendations about implementation
// - Algorithms: Formal descriptions of algorithm functions, including pseudocode
// - Examples: Specific applications or illustrations of algorithm operations
//
// For each segment you identify, please:
// 1. Provide a concise description that summarizes the segment's content
// 2. Extract the exact first 100 characters of the segment from the text
// 3. Assign the most appropriate semantic label from the categories above
//
// Your output should be a JSON array where each object contains:
// - A "description" field with your summary
// - A "first" field containing the first 100 characters of the segment
// - A "label" field with one of the specified category labels
//
// Be sure to include segments which are LaTeX formulas, enumerated lists and diagrams.
