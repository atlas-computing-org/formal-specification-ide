// %% [markdown]
// # Semantic Categories

// %% [markdown]
// Pass a list of segments to the LLM and ask for labels and descriptions.

// %%
import { SystemMessage, HumanMessage } from "@langchain/core/messages";
import { ChatPromptTemplate, MessagesPlaceholder } from "@langchain/core/prompts";
import { JsonOutputParser } from "@langchain/core/output_parsers";
import { readFileSync } from 'node:fs';

import { EXPERIMENTS_DIR, SERVER_DATA_DIR } from '../server/src/util/fileUtils.ts';
import { getNotebookLogger } from '../server/src/Logger.ts';
import { newModel } from '../server/src/agents/agent.ts';

const prompt = ChatPromptTemplate.fromMessages([ new MessagesPlaceholder("messages") ]);
const llm = newModel("Anthropic");
const parser = new JsonOutputParser();
const chain = prompt.pipe(llm).pipe(parser);

const logger = getNotebookLogger();
const lhsText = readFileSync(`${SERVER_DATA_DIR}/SHA-1-md/selected-text.txt`, 'utf-8');
const PROMPT = readFileSync(`${EXPERIMENTS_DIR}/annotateNodePromptCategories6.txt`, 'utf-8');

const segments = lhsText.split('\n\n');
var userInput = JSON.stringify(segments, null, 2);
var output = await chain.invoke({ messages: [
  new SystemMessage(PROMPT),
  new HumanMessage(userInput)
]});
logger.info(output);
// Out:
// [
//   {
//     description: "Describes the SHIFTROWS transformation which moves bytes in each row by r positions to the left",
//     text: "SHIFTROWS() is illustrated in Figure 3. In that representation of the state, the effect is to move each",
//     label: "Definitions"
//   },
//   {
//     description: "Reference to Figure 3 showing the SHIFTROWS operation",
//     text: "[Figure 3. Illustration of SHIFTROWS()]",
//     label: "Examples"
//   },
//   {
//     description: "Section header for the MixColumns transformation",
//     text: "### 5.1.3 MixColumns()",
//     label: "Header"
//   },
//   {
//     description: "Definition of the MixColumns transformation that multiplies each column of the state by a fixed matrix",
//     text: "MixColumns() is a transformation of the state that multiplies each of the four columns of the state by",
//     label: "Definitions"
//   },
//   {
//     description: "Mathematical formula showing the matrix multiplication in MixColumns transformation",
//     text: "\\left[\\begin{array}{l}\n" +
//       "s_{0, c}^{\\prime} \\\\\n" +
//       "s_{1, c}^{\\prime} \\\\\n" +
//       "s_{2, c}^{\\prime} \\\\\n" +
//       "s_{3, c}^{\\prime}\n" +
//       "\\end{array}\\right]=\\left[\\begin{array}{llll}\n" +
//       "02 & 03 & 01 & 01 \\\\\n" +
//       "01 & 02 & 03 & 01 \\\\\n" +
//       "01 & 01 & 02 & 03 \\\\\n" +
//       "03 & 01 & 01 & 02\n" +
//       "\\end{array}\\right]\\left[\\begin{array}{l}\n" +
//       "s_{0, c} \\\\\n" +
//       "s_{1, c} \\\\\n" +
//       "s_{2, c} \\\\\n" +
//       "s_{3, c}\n" +
//       "\\end{array}\\right] \\quad \\text{for } 0 \\leq c<4",
//     label: "Definitions"
//   },
//   {
//     description: "Detailed mathematical definition of how individual output bytes are calculated in MixColumns",
//     text: "so that the individual output bytes are defined as follows:\n" +
//       "$$\n" +
//       "\\begin{aligned}\n" +
//       "s_{0, c}^{\\prime} & =(\\{02\\} \\bullet s_{0, c}) \\oplus (\\{03\\} \\bullet s_{1, c}) \\oplus s_{2, c} \\oplus s_{3, c} \\\\\n" +
//       "s_{1, c}^{\\prime} & =s_{0, c} \\oplus (\\{02\\} \\bullet s_{1, c}) \\oplus (\\{03\\} \\bullet s_{2, c}) \\oplus s_{3, c} \\\\\n" +
//       "s_{2, c}^{\\prime} & =s_{0, c} \\oplus s_{1, c} \\oplus (\\{02\\} \\bullet s_{2, c}) \\oplus (\\{03\\} \\bullet s_{3, c}) \\\\\n" +
//       "s_{3, c}^{\\prime} & =(\\{03\\} \\bullet s_{0, c}) \\oplus s_{1, c} \\oplus s_{2, c} \\oplus (\\{02\\} \\bullet s_{3, c}).\n" +
//       "\\end{aligned}",
//     label: "Definitions"
//   },
//   {
//     description: "Reference to Figure 4 showing the MixColumns operation",
//     text: "Figure 4 illustrates MixColumns().",
//     label: "Examples"
//   },
//   {
//     description: "Reference to Figure 4 showing the MixColumns operation",
//     text: "[Figure 4. Illustration of MixColumns()]",
//     label: "Examples"
//   },
//   {
//     description: "Section header for the AddRoundKey transformation",
//     text: "### 5.1.4 ADDROUNDKEY()",
//     label: "Header"
//   },
//   {
//     description: "Definition of the AddRoundKey transformation that combines the state with a round key using XOR",
//     text: "ADDROUNDKEY() is a transformation of the state in which a round key is combined with the state by applyi",
//     label: "Definitions"
//   },
//   {
//     description: "Additional explanation of how AddRoundKey is used in the cipher algorithm",
//     text: "The action of this transformation is illustrated in Fig. 5, where $l=4*$ round. The byte address within",
//     label: "Elaborations"
//   },
//   {
//     description: "Reference to Figure 5 showing the AddRoundKey operation",
//     text: "[Figure 5. Illustration of ADDROUNDKEY()]",
//     label: "Examples"
//   },
//   {
//     description: "Pseudocode for the KeyExpansion algorithm that generates the round keys",
//     text: "```\n" +
//       "Algorithm 2 Pseudocode for KEYEXPANSION()\n" +
//       "    procedure KEYEXPANSION(key)\n" +
//       "        i ← 0\n" +
//       "        while i",
//     label: "Algorithms"
//   },
//   {
//     description: "Reference to figures illustrating KeyExpansion for different AES key sizes",
//     text: "Figures 6, 7, and 8 illustrate KEYEXPANSION() for AES-128, AES-192, and AES-256.",
//     label: "Examples"
//   },
//   {
//     description: "Section header for the inverse cipher algorithm",
//     text: "## 5.3 INVCIPHER()",
//     label: "Header"
//   },
//   {
//     description: "Introduction to the inverse cipher that reverses the transformations of the cipher",
//     text: "To implement INVCIPHER(), the transformations in the specification of CIPHER() (Section 5.1) are inverte",
//     label: "Definitions"
//   },
//   {
//     description: "Reference to Figure 6 showing KeyExpansion for AES-128",
//     text: "[Figure 6. KEYEXPANSION() of AES-128 to generate the words $w[i]$ for $4 \\leq i<44$, where $l$ ranges o",
//     label: "Examples"
//   },
//   {
//     description: "Reference to Figure 7 showing KeyExpansion for AES-192",
//     text: "[Figure 7. KEYEXPANSION() of AES-192 to generate the words $w[i]$ for $6 \\leq i<52$, where $l$ ranges o",
//     label: "Examples"
//   },
//   {
//     description: "Reference to Figure 8 showing KeyExpansion for AES-256",
//     text: "[Figure 8. KEYEXPANSION() of AES-256 to generate the words $w[i]$ for $8 \\leq i<60$, where $l$ ranges o",
//     label: "Examples"
//   },
//   {
//     description: "Section header for the inverse MixColumns transformation",
//     text: "### 5.3.3 InvMixColumns()",
//     label: "Header"
//   },
//   {
//     description: "Definition of the InvMixColumns transformation that is the inverse of MixColumns",
//     text: "InvMixColumns() is the inverse of MixColumns(). In particular, InvMixColumns() multiplies each of the fo",
//     label: "Definitions"
//   },
//   {
//     description: "Mathematical formula showing the matrix multiplication in InvMixColumns transformation",
//     text: "\\left[\\begin{array}{c}\n" +
//       "s_{0, c}^{\\prime} \\\\\n" +
//       "s_{1, c}^{\\prime} \\\\\n" +
//       "s_{2, c}^{\\prime} \\\\\n" +
//       "s_{3, c}^{\\prime}\n" +
//       "\\end{array}\\right]=\\left[\\begin{array}{cccc}\n" +
//       "0\\mathrm{e} & 0\\mathrm{b} & 0\\mathrm{d} & 09 \\\\\n" +
//       "09 & 0\\mathrm{e} & 0\\mathrm{b} & 0\\mathrm{d} \\\\\n" +
//       "0\\mathrm{d} & 09 & 0\\mathrm{e} & 0\\mathrm{b} \\\\\n" +
//       "0\\mathrm{b} & 0\\mathrm{d} & 09 & 0\\mathrm{e}\n" +
//       "\\end{array}\\right]\\left[\\begin{array}{l}\n" +
//       "s_{0, c} \\\\\n" +
//       "s_{1, c} \\\\\n" +
//       "s_{2, c} \\\\\n" +
//       "s_{3, c}\n" +
//       "\\end{array}\\right] \\quad \\text{for } 0 \\leq c<4",
//     label: "Definitions"
//   },
//   {
//     description: "Detailed mathematical definition of how individual output bytes are calculated in InvMixColumns",
//     text: "As a result of this matrix multiplication, the four bytes in a column are replaced by the following:\n" +
//       "$$\n" +
//       "\\",
//     label: "Definitions"
//   },
//   {
//     description: "Section header for the inverse of AddRoundKey transformation",
//     text: "### 5.3.4 Inverse of ADDROUNDKEY()",
//     label: "Header"
//   },
//   {
//     description: "Statement that AddRoundKey is its own inverse operation",
//     text: "ADDROUNDKEY(), described in Section 5.1.4, is its own inverse.",
//     label: "Definitions"
//   },
//   {
//     description: "Section header for the equivalent inverse cipher",
//     text: "### 5.3.5 EQINVCIPHER()",
//     label: "Header"
//   },
//   {
//     description: "Explanation of the equivalent inverse cipher as an alternative to the standard inverse cipher",
//     text: "Several properties of the AES algorithm allow for an alternative specification of the inverse of CIPHER(",
//     label: "Intent"
//   },
//   {
//     description: "Introduction to the pseudocode for the equivalent inverse cipher and its key schedule",
//     text: "The pseudocode for the equivalent inverse cipher, given in Alg. 4, uses a modified key schedule, denoted",
//     label: "Elaborations"
//   },
//   {
//     description: "Pseudocode for the equivalent inverse cipher algorithm",
//     text: "```\n" +
//       "Algorithm 4 Pseudocode for EQINVCIPHER()\n" +
//       "    procedure EQINVCIPHER(in, Nr, dw)\n" +
//       "        state ← in\n" +
//       " ",
//     label: "Algorithms"
//   },
//   {
//     description: "Pseudocode for the key expansion algorithm for the equivalent inverse cipher",
//     text: "```\n" +
//       "Algorithm 5 Pseudocode for KEYEXPANSIONEIC()\n" +
//       "    procedure KEYEXPANSIONEIC(key)\n" +
//       "        i ← 0\n" +
//       "     ",
//     label: "Algorithms"
//   },
//   {
//     description: "Explanation of how the key schedule for the equivalent inverse cipher differs from the standard key schedule",
//     text: "The first and last round keys in $dw$ are the same as in $w$; the modification of the other round keys i",
//     label: "Elaborations"
//   }
// ]

// %%
console.log(JSON.stringify(output, null, 2));
// Out:
// [
//   {
//     "description": "Section header for the preprocessing section",
//     "text": "# 5. PREPROCESSING",
//     "label": "Header"
//   },
//   {
//     "description": "Overview of the three preprocessing steps for the hash algorithm",
//     "text": "Preprocessing consists of three steps: padding the message, $M$ (Sec. 5.1), parsing the message into ",
//     "label": "Definitions"
//   },
//   {
//     "description": "Subsection header for padding the message",
//     "text": "## 5.1 Padding the Message",
//     "label": "Header"
//   },
//   {
//     "description": "Explanation of the purpose of padding in the hash algorithm",
//     "text": "The purpose of this padding is to ensure that the padded message is a multiple of 512 or 1024 bits, d",
//     "label": "Intent"
//   },
//   {
//     "description": "Subsubsection header for specific hash algorithms",
//     "text": "### 5.1.1 SHA-1, SHA-224 and SHA-256",
//     "label": "Header"
//   },
//   {
//     "description": "Detailed specification of the padding algorithm for SHA-1, SHA-224, and SHA-256",
//     "text": "Suppose that the length of the message, $M$, is $\\ell$ bits. Append the bit \"1\" to the end of the me",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Reference to an image showing padded message representation",
//     "text": "[IMAGE: Padded message representation]",
//     "label": "Examples"
//   },
//   {
//     "description": "Requirement about the length of the padded message",
//     "text": "The length of the padded message should now be a multiple of 512 bits.",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsection header for parsing the message",
//     "text": "## 5.2 Parsing the Message",
//     "label": "Header"
//   },
//   {
//     "description": "General requirement for parsing the message into blocks",
//     "text": "The message and its padding must be parsed into $N m$-bit blocks.",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsubsection header for specific hash algorithms",
//     "text": "### 5.2.1 SHA-1, SHA-224 and SHA-256",
//     "label": "Header"
//   },
//   {
//     "description": "Detailed specification of the parsing algorithm for SHA-1, SHA-224, and SHA-256",
//     "text": "For SHA-1, SHA-224 and SHA-256, the message and its padding are parsed into $N$ 512-bit blocks, $M^{",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Subsection header for setting the initial hash value",
//     "text": "## 5.3 Setting the Initial Hash Value ($H^{(0)}$)",
//     "label": "Header"
//   },
//   {
//     "description": "Explanation of the initial hash value requirement",
//     "text": "Before hash computation begins for each of the secure hash algorithms, the initial hash value, $H^{(0)",
//     "label": "Requirements"
//   },
//   {
//     "description": "Subsubsection header for SHA-1 initial hash value",
//     "text": "### 5.3.1 SHA-1",
//     "label": "Header"
//   },
//   {
//     "description": "Specification of the initial hash value for SHA-1",
//     "text": "For SHA-1, the initial hash value, $H^{(0)}$, shall consist of the following five 32-bit words, in he",
//     "label": "Definitions"
//   },
//   {
//     "description": "Mathematical representation of the initial hash values for SHA-1",
//     "text": "$$\n\\begin{aligned}\nH_{0}^{(0)} &= 67452301 \\\\\nH_{1}^{(0)} &= \\text{efcdab89} \\\\\nH_{2}^{(0)} &= 98",
//     "label": "Definitions"
//   },
//   {
//     "description": "Section header for secure hash algorithms",
//     "text": "# 6. SECURE HASH ALGORITHMS",
//     "label": "Header"
//   },
//   {
//     "description": "Explanation of the organization of the hash algorithm descriptions",
//     "text": "In the following sections, the hash algorithms are not described in ascending order of size. SHA-256 is",
//     "label": "Elaborations"
//   },
//   {
//     "description": "Statement about alternate computation methods that yield identical results",
//     "text": "For each of the secure hash algorithms, there may exist alternate computation methods that yield ident",
//     "label": "Preferences"
//   },
//   {
//     "description": "Subsection header for SHA-1",
//     "text": "## 6.1 SHA-1",
//     "label": "Header"
//   },
//   {
//     "description": "Overview of SHA-1 algorithm characteristics and components",
//     "text": "SHA-1 may be used to hash a message, $M$, having a length of $\\ell$ bits, where $0 \\leq \\ell < 2^{64}$",
//     "label": "Definitions"
//   },
//   {
//     "description": "Definition of the variables and components used in SHA-1",
//     "text": "The words of the message schedule are labeled $W_{0}, W_{1}, \\ldots, W_{79}$. The five working variabl",
//     "label": "Definitions"
//   },
//   {
//     "description": "Subsubsection header for SHA-1 preprocessing",
//     "text": "### 6.1.1 SHA-1 Preprocessing",
//     "label": "Header"
//   },
//   {
//     "description": "Steps for SHA-1 preprocessing",
//     "text": "1. Set the initial hash value, $H^{(0)}$, as specified in Sec. 5.3.1.\n2. The message is padded and pa",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Subsubsection header for SHA-1 hash computation",
//     "text": "### 6.1.2 SHA-1 Hash Computation",
//     "label": "Header"
//   },
//   {
//     "description": "Reference to functions and constants used in SHA-1 hash computation",
//     "text": "The SHA-1 hash computation uses functions and constants previously defined in Sec. 4.1.1 and Sec. 4.2.",
//     "label": "Elaborations"
//   },
//   {
//     "description": "Introduction to the message block processing steps",
//     "text": "Each message block, $M^{(1)}, M^{(2)}, \\ldots, M^{(N)}$, is processed in order, using the following st",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Detailed algorithm steps for SHA-1 hash computation",
//     "text": "For $i=1$ to $N$:\n{\n1. Prepare the message schedule, $\\{W_{t}\\}$:\n   $$W_{t}= \\begin{cases}\n   M_{t}^",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Final step of the SHA-1 algorithm to produce the message digest",
//     "text": "After repeating steps one through four a total of $N$ times (i.e., after processing $M^{(N)}$), the re",
//     "label": "Algorithms"
//   },
//   {
//     "description": "Mathematical representation of the final message digest",
//     "text": "$$H_{0}^{(N)}||H_{1}^{(N)}||H_{2}^{(N)}||H_{3}^{(N)}||H_{4}^{(N)}$$\n",
//     "label": "Definitions"
//   }
// ]

// %%
console.log("SEGMENTS LENGTH", segments.length);
console.log("LLM OUTPUT LENGTH", output.length);
for (let i = 0; i < segments.length; i++) {
  const outtext = output[i].text;
  const outlength = outtext.length;
  const segtext = segments[i].substring(0, outlength);
  if (segtext !== outtext) { 
    console.log(`${i} Mismatch`); 
    console.log("SEGMENT");
    console.log(segtext);
    console.log("LLM OUTPUT");
    console.log(outtext);
  } else { 
    console.log(`${i} Match`); 
  }
}
// Out:
// SEGMENTS LENGTH 32
// LLM OUTPUT LENGTH 31
// 0 Match
// 1 Match
// 2 Match
// 3 Match
// 4 Mismatch
// SEGMENT
// Thus,
// $$
// \left[\begin{array}{l}
// s_{0, c}^{\prime} \\
// s_{1, c}^{\prime} \\
// s_{2, c}^{\prime} \\
// s_{3, c}^{\prime}
// \end{array}\right]=\left[\begin{array}{llll}
// 02 & 03 & 01 & 01 \\
// 01 & 02 & 03 & 01 \\
// 01 & 01 & 02 & 03 \\
// 03 & 01 & 01 & 02
// \end{array}\right]\left[\begin{array}{l}
// s_{0, c} \\
// s_{1, c} \\
// s_{2, c} \\
// s_{3, c}
// \end{array}\right] \quad \text{for } 0
// LLM OUTPUT
// \left[\begin{array}{l}
// s_{0, c}^{\prime} \\
// s_{1, c}^{\prime} \\
// s_{2, c}^{\prime} \\
// s_{3, c}^{\prime}
// \end{array}\right]=\left[\begin{array}{llll}
// 02 & 03 & 01 & 01 \\
// 01 & 02 & 03 & 01 \\
// 01 & 01 & 02 & 03 \\
// 03 & 01 & 01 & 02
// \end{array}\right]\left[\begin{array}{l}
// s_{0, c} \\
// s_{1, c} \\
// s_{2, c} \\
// s_{3, c}
// \end{array}\right] \quad \text{for } 0 \leq c<4
// 5 Match
// 6 Match
// 7 Match
// 8 Match
// 9 Match
// 10 Match
// 11 Match
// 12 Match
// 13 Match
// 14 Match
// 15 Match
// 16 Mismatch
// SEGMENT
// INVCIPHER() is described in the pseudocode in Alg. 3, where the array $w$ denotes the key schedule, as
// LLM OUTPUT
// [Figure 6. KEYEXPANSION() of AES-128 to generate the words $w[i]$ for $4 \leq i<44$, where $l$ ranges o
// 17 Mismatch
// SEGMENT
// [Figure 6. KEYEXPANSION() of AES-128 to generate the words $w[i]$ for $4 \leq i<44$, where $l$ ranges o
// LLM OUTPUT
// [Figure 7. KEYEXPANSION() of AES-192 to generate the words $w[i]$ for $6 \leq i<52$, where $l$ ranges o
// 18 Mismatch
// SEGMENT
// [Figure 7. KEYEXPANSION() of AES-192 to generate the words $w[i]$ for $6 \leq i<52$, where $l$ ranges o
// LLM OUTPUT
// [Figure 8. KEYEXPANSION() of AES-256 to generate the words $w[i]$ for $8 \leq i<60$, where $l$ ranges o
// 19 Mismatch
// SEGMENT
// [Figure 8. KEYEXPANSION()
// LLM OUTPUT
// ### 5.3.3 InvMixColumns()
// 20 Mismatch
// SEGMENT
// ### 5.3.3 InvMixColumns()
// LLM OUTPUT
// InvMixColumns() is the inverse of MixColumns(). In particular, InvMixColumns() multiplies each of the fo
// 21 Mismatch
// SEGMENT
// InvMixColumns() is the inverse of MixColumns(). In particular, InvMixColumns() multiplies each of the four columns of the state by a single fixed matrix, as described in Section 4.3, with its entries taken from the following word:
// $$
// [a_{0}, a_{1}, a_{2}, a_{3}]=[\{0\mathrm{e}\},\{09\},\{0\mathrm{d}\},\{0\mathrm{b}\}].
// $$
// LLM OUTPUT
// \left[\begin{array}{c}
// s_{0, c}^{\prime} \\
// s_{1, c}^{\prime} \\
// s_{2, c}^{\prime} \\
// s_{3, c}^{\prime}
// \end{array}\right]=\left[\begin{array}{cccc}
// 0\mathrm{e} & 0\mathrm{b} & 0\mathrm{d} & 09 \\
// 09 & 0\mathrm{e} & 0\mathrm{b} & 0\mathrm{d} \\
// 0\mathrm{d} & 09 & 0\mathrm{e} & 0\mathrm{b} \\
// 0\mathrm{b} & 0\mathrm{d} & 09 & 0\mathrm{e}
// \end{array}\right]\left[\begin{array}{l}
// s_{0, c} \\
// s_{1, c} \\
// s_{2, c} \\
// s_{3, c}
// \end{array}\right] \quad \text{for } 0 \leq c<4
// 22 Mismatch
// SEGMENT
// Thus,
// $$
// \left[\begin{array}{c}
// s_{0, c}^{\prime} \\
// s_{1, c}^{\prime} \\
// s_{2, c}^{\prime} \\
// s_{3, c}^{
// LLM OUTPUT
// As a result of this matrix multiplication, the four bytes in a column are replaced by the following:
// $$
// \
// 23 Mismatch
// SEGMENT
// As a result of this matrix multipl
// LLM OUTPUT
// ### 5.3.4 Inverse of ADDROUNDKEY()
// 24 Mismatch
// SEGMENT
// ### 5.3.4 Inverse of ADDROUNDKEY()
// LLM OUTPUT
// ADDROUNDKEY(), described in Section 5.1.4, is its own inverse.
// 25 Mismatch
// SEGMENT
// ADDROUNDKEY(), describe
// LLM OUTPUT
// ### 5.3.5 EQINVCIPHER()
// 26 Mismatch
// SEGMENT
// ### 5.3.5 EQINVCIPHER()
// LLM OUTPUT
// Several properties of the AES algorithm allow for an alternative specification of the inverse of CIPHER(
// 27 Mismatch
// SEGMENT
// Several properties of the AES algorithm allow for an alternative specification of the inverse of CIPHER(
// LLM OUTPUT
// The pseudocode for the equivalent inverse cipher, given in Alg. 4, uses a modified key schedule, denoted
// 28 Mismatch
// SEGMENT
// The pseudocode for the equivalent inverse cipher, given in Alg. 4, uses a modified key schedule, denote
// LLM OUTPUT
// ```
// Algorithm 4 Pseudocode for EQINVCIPHER()
//     procedure EQINVCIPHER(in, Nr, dw)
//         state ← in
//
// 29 Mismatch
// SEGMENT
// ```
// Algorithm 4 Pseudocode for EQINVCIPHER()
//     procedure EQINVCIPHER(in, Nr, dw)
//         state ← in
//
// LLM OUTPUT
// ```
// Algorithm 5 Pseudocode for KEYEXPANSIONEIC()
//     procedure KEYEXPANSIONEIC(key)
//         i ← 0
//
// 30 Mismatch
// SEGMENT
// ```
// Algorithm 5 Pseudocode for KEYEXPANSIONEIC()
//     procedure KEYEXPANSIONEIC(key)
//         i ← 0
//
// LLM OUTPUT
// The first and last round keys in $dw$ are the same as in $w$; the modification of the other round keys i
// Stack trace:
// TypeError: Cannot read properties of undefined (reading 'text')
//     at <anonymous>:4:29
